# %%
import pyautogui
import numpy as np

# %%
#Setting the initial height,breadth and load position
height=300
breadth=350
loadposition=1000

# %%
#setting the variables
i=0
load_value=1
y=21
load_position_var=1

# %%
while (i<1201):
    
    if (load_var<11):
        load=100*load_var
        print("loop load_var",load_var)
    print(i)
    print("load_position_var="+str(load_position_var))
    # Move to the design point
    pyautogui.moveTo(1170,226+y,10)    
    pyautogui.click(1170, 226+y)
    y=y+21
    
    #right click on  the design point    
    pyautogui.click(button='right')
    
    #Click on "set as current"
    pyautogui.moveTo(1224,328+y,1) 
    pyautogui.click(1224,328+y )
    y=y+21
    
    #Move to project tab
    pyautogui.moveTo(140, 89,15)
    
    #click on project
    pyautogui.click(140,89 )
    
    #click on model
    pyautogui.moveTo(408, 286,2)
    pyautogui.click(clicks=2)
    
    #move to von mises stress  
    pyautogui.moveTo(236, 553,25)
    pyautogui.click()
    pyautogui.click(button='right')   
    
    #Click on export of von mises stress
    pyautogui.moveTo(264,598,1)
    pyautogui.click(264,598)
    
    #Click on excel file
    pyautogui.moveTo(601,601,1)
    pyautogui.click(601,601) 
    
    #Click on back symbol
    pyautogui.moveTo(1126,357,1)
    pyautogui.click(1126,357)
    
    #select the stress folder
    pyautogui.moveTo(847,444,1)
    pyautogui.click(847,444,clicks=2)
    pyautogui.moveTo(943,763,2) 
    
    #Go to naming section and enter the name accordingly
    pyautogui.click(943,763)
    pyautogui.typewrite(f"B_{breadth}_H_{height}_X_{loadposition}_P_{load}")
    pyautogui.press('enter')
    
       
    #move to Total deformation
    pyautogui.moveTo(208, 578,2)
    pyautogui.click(208,578)
    pyautogui.click(button='right')
    
    #Click on export of total deformation
    pyautogui.moveTo(360,624,2)
    pyautogui.click(360,624)
    
    #Click on the excel file
    pyautogui.moveTo(589,620,2)
    pyautogui.click(589,620) 
    
    #Click on the back symbol
    pyautogui.moveTo(1126,357,2)
    pyautogui.click(1126,357)
    
    #Select the deformation folder
    pyautogui.moveTo(879,420,2)
    pyautogui.click(879,420,clicks=2)
    
    #save the file
    pyautogui.moveTo(1248,758,2)
    pyautogui.click(1248,758)
    
    # update 'load_var' and 'load_position_var'      
    load_position_var=load_position_var+1
    a=a+1
   
    #close the model window
    pyautogui.moveTo(1900,10,2)
    pyautogui.click(1900,10)
    
    #move to parameter set
    pyautogui.moveTo(242,88,5)
    
    #click on parameter set
    pyautogui.click() 
    
    # put conditions for 'load_var' and 'load_position_var' for 
    if(load_var==11):
        load_var=1
    if(load_position_var==12):
        load_position_var=2
        
    # Scrolling after every 24 design points    
    scroll_range=np.arange(139,2299,24)
    if(i in scroll_range):
        pyautogui.click(1170,226)
        pyautogui.scroll(-1500)
        y=21
        
    #Consider the height and breadth variation    
    list_height=np.arange(50,5000,50)
    list_breadth=np.arange(351,2457,350) 
    
      
    if(i in list_height):
        height=height+50
        print("height",height)
       
    if(i in list_breadth):
        breadth=breadth+50
        print("breadth",breadth)
       
    
    #Changing the load position to 1000 after one cycle
    if(load_position_var==11):
        loadposition=loadposition-200
        if(loadposition==0):
            loadposition=1000
       
    i=i+1
# Out:
# loop a 2
# 1192
# b=2
# loop a 3
# 1193
# b=3
# loop a 4
# 1194
# b=4
# loop a 5
# 1195
# b=5
# loop a 6
# 1196
# b=6
# loop a 7
# 1197
# b=7
# loop a 8
# 1198
# b=8
# loop a 9
# 1199
# b=9
# loop a 10
# 1200
# b=10
# height 350
# loop a 1
# 1201
# b=11
# loop a 2
# 1202
# b=2
# loop a 3
# 1203
# b=3
# loop a 4
# 1204
# b=4
# loop a 5
# 1205
# b=5
# loop a 6
# 1206
# b=6
# loop a 7
# 1207
# b=7
# ---------------------------------------------------------------------------
# FailSafeException                         Traceback (most recent call last)
# <ipython-input-33-7be9f1f94a5e> in <module>
#      45
#      46     pyautogui.click(943,763)
# ---> 47     pyautogui.typewrite(f"B_{breadth}_H_{height}_X_{loadposition}_P_{load}")
#      48     pyautogui.press('enter')
#      49
#
# c:\users\lakhan\appdata\local\programs\python\python39\lib\site-packages\pyautogui\__init__.py in wrapper(*args, **kwargs)
#     583     @functools.wraps(wrappedFunction)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# FailSafeException                         Traceback (most recent call last)
# <ipython-input-43-2d20136b2e78> in <module>
#       1 pyautogui.click(230,467)
#       2 pyautogui.PAUSE = 10
# ----> 3 pyautogui.moveTo(122,345,5)
#
# c:\users\lakhan\appdata\local\programs\python\python39\lib\site-packages\pyautogui\__init__.py in wrapper(*args, **kwargs)
#     584     def wrapper(*args, **kwargs):
#     585         failSafeCheck()
# --> 586         returnVal = wrappedFunction(*args, **kwargs)
#     587         _handlePause(kwargs.get("_pause", True))
#     588         return returnVal
#
# c:\users\lakhan\appdata\local\programs\python\python39\lib\site-packages\pyautogui\__init__.py in moveTo(x, y, duration, tween, logScreenshot, _pause)
#    1269
#    1270     _logScreenshot(logScreenshot, "moveTo", "%s,%s" % (x, y), folder=".")
# -> 1271     _mouseMoveDrag("move", x, y, 0, 0, duration, tween)
#    1272
# ...

# %% [markdown]
# ## -------------------------------------END-------------------------------------------------
